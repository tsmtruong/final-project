# %%
# importing dependencies
import pandas as pd
import glob
import os

# %%
# setting path
files = os.path.join("Resources/Schools/greatschools*.csv")

# %%
#list of merged files returned
files = glob.glob(files)

# %%
# joining files 
school_df = pd.concat(map(pd.read_csv, files), ignore_index=True)

school_df.head(10)
# Out:
#    circle-rating--small                            name  \
# 0                  10.0     Bird Rock Elementary School
# 1                   9.0              Preuss School Ucsd
# 2                   9.0      La Jolla Elementary School
# 3                   9.0  Torrey Pines Elementary School
# 4                   8.0            La Jolla High School
# 5                   8.0         Muirlands Middle School
# 6                   9.0   Pacific Rim Elementary School
# 7                   9.0       Aviara Oaks Middle School
# 8                   9.0          Sage Creek High School
# 9                   9.0   Aviara Oaks Elementary School
#
#                                            address  \
# 0  5371 La Jolla Hermosa Ave., La Jolla, CA, 92037
# 1           9500 Gilman Drive, La Jolla, CA, 92093
# 2             1111 Marine St., La Jolla, CA, 92037
# 3        8350 Cliffridge Ave., La Jolla, CA, 92037
# 4            750 Nautilus St., La Jolla, CA, 92037
# 5           1056 Nautilus St., La Jolla, CA, 92037
# 6    1100 Camino De Las Ondas, Carlsbad, CA, 92011
# 7          6880 Ambrosia Lane, Carlsbad, CA, 92011
# 8            3900 Cannon Road, Carlsbad, CA, 92010
# 9          6900 Ambrosia Lane, Carlsbad, CA, 92011
#
#   tablescraper-selected-row 2 tablescraper-selected-row 3  \
# 0                         K-5                         450
# 1                        6-12                         836
# 2                         K-5                         572
# 3                         K-5                         475
# 4                        9-12                        1406
# 5                         6-8                         924
# 6                         K-5                       825.0
# 7                         6-8                      1050.0
# 8                        9-12                      1320.0
# 9                         K-5                       675.0
#
#   tablescraper-selected-row 4  \
# 0                        20:1
# 1                        20:1
# 2                        18:1
# 3                        20:1
# 4                        25:1
# 5                        22:1
# 6                        27:1
# 7                        28:1
# 8                        28:1
# 9                        27:1
#
#                       tablescraper-selected-row href rating-circle-small  \
# 0  https://www.greatschools.org/california/la-jol...                 NaN
# 1  https://www.greatschools.org/california/la-jol...                 NaN
# 2  https://www.greatschools.org/california/la-jol...                 NaN
# 3  https://www.greatschools.org/california/la-jol...                 NaN
# 4  https://www.greatschools.org/california/la-jol...                 NaN
# 5  https://www.greatschools.org/california/la-jol...                 NaN
# 6                                                NaN                 /10
# 7                                                NaN                 /10
# 8                                                NaN                 /10
# 9                                                NaN                 /10
#
#            scale                                          name href  \
# 0            NaN                                                NaN
# 1            NaN                                                NaN
# 2            NaN                                                NaN
# 3            NaN                                                NaN
# 4            NaN                                                NaN
# 5            NaN                                                NaN
# 6  Above average  https://www.greatschools.org/california/carlsb...
# 7  Above average  https://www.greatschools.org/california/carlsb...
# 8  Above average  https://www.greatschools.org/california/carlsb...
# 9  Above average  https://www.greatschools.org/california/carlsb...
#
#   tablescraper-selected-row       tablescraper-selected-row 6  \
# 0                       NaN                               NaN
# 1                       NaN                               NaN
# 2                       NaN                               NaN
# 3                       NaN                               NaN
# 4                       NaN                               NaN
# 5                       NaN                               NaN
# 6           Public district  Carlsbad Unified School District
# 7           Public district  Carlsbad Unified School District
# 8           Public district  Carlsbad Unified School District
# 9           Public district  Carlsbad Unified School District
#
#   tablescraper-selected-row href 2
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
