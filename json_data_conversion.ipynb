# %%
# Import Dependencies
import pandas as pd

# %%
# Read in data
file_path = 'Resources/Clean/San_Diego_Housing_Data.csv'
data = pd.read_csv(file_path)
data_df = pd.DataFrame(data)
data_df.head()
# Out:
#    Geographic Area Name  Households_Total  Households_Total_Less than $10,000  \
# 0                 91901            6150.0                                 2.4
# 1                 91902            6045.0                                 2.8
# 2                 91906            1282.0                                 4.6
# 3                 91910           24599.0                                 4.4
# 4                 91911           25145.0                                 3.2
#
#    Households_Total_$10,000 to $14,999  Households_Total_$15,000 to $24,999  \
# 0                                  1.0                                  5.3
# 1                                  0.6                                  3.1
# 2                                  2.7                                  7.4
# 3                                  5.4                                  6.7
# 4                                  5.2                                  7.7
#
#    Households_Total_$25,000 to $34,999  Households_Total_$35,000 to $49,999  \
# 0                                 10.5                                  8.0
# 1                                  5.1                                  7.6
# 2                                 12.6                                 27.1
# 3                                  9.2                                 10.4
# 4                                  9.7                                 11.1
#
#    Households_Total_$50,000 to $74,999  Households_Total_$75,000 to $99,999  \
# 0                                  9.4                                 16.4
# 1                                 12.1                                 14.3
# 2                                 11.2                                  6.4
# 3                                 17.0                                 13.2
# 4                                 18.7                                 12.1
#
#    Households_Total_$100,000 to $149,999  ...  \
# 0                                   19.8  ...
# 1                                   23.1  ...
# 2                                   17.9  ...
# 3                                   17.3  ...
# 4                                   19.5  ...
#
#    Nonfamily households_Total_$25,000 to $34,999  \
# 0                                           23.4
# 1                                           13.5
# 2                                            8.9
# 3                                           11.2
# 4                                           16.8
#
#    Nonfamily households_Total_$35,000 to $49,999  \
# 0                                           14.8
# 1                                           19.1
# 2                                           41.0
# 3                                           11.9
# 4                                           14.1
#
#    Nonfamily households_Total_$50,000 to $74,999  \
# 0                                           13.9
# 1                                            9.8
# 2                                            7.0
# 3                                           18.0
# 4                                           15.6
#
#    Nonfamily households_Total_$75,000 to $99,999  \
# 0                                           12.6
# 1                                           13.9
# 2                                            0.8
# 3                                           10.9
# 4                                            8.5
#
#    Nonfamily households_Total_$100,000 to $149,999  \
# 0                                             12.3
# 1                                             18.6
# 2                                              0.0
# 3                                              9.1
# 4                                              6.3
#
#    Nonfamily households_Total_$150,000 to $199,999  \
# 0                                              3.3
# 1                                              7.8
# 2                                              4.3
# 3                                              2.4
# 4                                              1.6
#
#    Nonfamily households_Total_$200,000 or more  \
# 0                                          2.0
# 1                                          7.4
# 2                                          0.0
# 3                                          2.9
# 4                                          0.7
#
#    Nonfamily households_Median income (dollars)  \
# 0                                       43523.0
# 1                                       70469.0
# 2                                       35991.0
# 3                                       40825.0
# 4                                       33231.0
#
#    Nonfamily households_Mean income (dollars)  \
# 0                                     62711.0
# 1                                    111325.0
# 2                                     37850.0
# 3                                     56747.0
# 4                                     45098.0
#
#    Nonfamily households_PERCENT ALLOCATED_Nonfamily income in the past 12 months
# 0                                               22.2
# 1                                               53.8
# 2                                               38.0
# 3                                               44.1
# 4                                               45.0
#
# [5 rows x 55 columns]

# %%
data_df = data_df.rename(columns={'Geographic Area Name':'Zip_Code'})
data_df.head()
# Out:
#    Zip_Code  Households_Total  Households_Total_Less than $10,000  \
# 0     91901            6150.0                                 2.4
# 1     91902            6045.0                                 2.8
# 2     91906            1282.0                                 4.6
# 3     91910           24599.0                                 4.4
# 4     91911           25145.0                                 3.2
#
#    Households_Total_$10,000 to $14,999  Households_Total_$15,000 to $24,999  \
# 0                                  1.0                                  5.3
# 1                                  0.6                                  3.1
# 2                                  2.7                                  7.4
# 3                                  5.4                                  6.7
# 4                                  5.2                                  7.7
#
#    Households_Total_$25,000 to $34,999  Households_Total_$35,000 to $49,999  \
# 0                                 10.5                                  8.0
# 1                                  5.1                                  7.6
# 2                                 12.6                                 27.1
# 3                                  9.2                                 10.4
# 4                                  9.7                                 11.1
#
#    Households_Total_$50,000 to $74,999  Households_Total_$75,000 to $99,999  \
# 0                                  9.4                                 16.4
# 1                                 12.1                                 14.3
# 2                                 11.2                                  6.4
# 3                                 17.0                                 13.2
# 4                                 18.7                                 12.1
#
#    Households_Total_$100,000 to $149,999  ...  \
# 0                                   19.8  ...
# 1                                   23.1  ...
# 2                                   17.9  ...
# 3                                   17.3  ...
# 4                                   19.5  ...
#
#    Nonfamily households_Total_$25,000 to $34,999  \
# 0                                           23.4
# 1                                           13.5
# 2                                            8.9
# 3                                           11.2
# 4                                           16.8
#
#    Nonfamily households_Total_$35,000 to $49,999  \
# 0                                           14.8
# 1                                           19.1
# 2                                           41.0
# 3                                           11.9
# 4                                           14.1
#
#    Nonfamily households_Total_$50,000 to $74,999  \
# 0                                           13.9
# 1                                            9.8
# 2                                            7.0
# 3                                           18.0
# 4                                           15.6
#
#    Nonfamily households_Total_$75,000 to $99,999  \
# 0                                           12.6
# 1                                           13.9
# 2                                            0.8
# 3                                           10.9
# 4                                            8.5
#
#    Nonfamily households_Total_$100,000 to $149,999  \
# 0                                             12.3
# 1                                             18.6
# 2                                              0.0
# 3                                              9.1
# 4                                              6.3
#
#    Nonfamily households_Total_$150,000 to $199,999  \
# 0                                              3.3
# 1                                              7.8
# 2                                              4.3
# 3                                              2.4
# 4                                              1.6
#
#    Nonfamily households_Total_$200,000 or more  \
# 0                                          2.0
# 1                                          7.4
# 2                                          0.0
# 3                                          2.9
# 4                                          0.7
#
#    Nonfamily households_Median income (dollars)  \
# 0                                       43523.0
# 1                                       70469.0
# 2                                       35991.0
# 3                                       40825.0
# 4                                       33231.0
#
#    Nonfamily households_Mean income (dollars)  \
# 0                                     62711.0
# 1                                    111325.0
# 2                                     37850.0
# 3                                     56747.0
# 4                                     45098.0
#
#    Nonfamily households_PERCENT ALLOCATED_Nonfamily income in the past 12 months
# 0                                               22.2
# 1                                               53.8
# 2                                               38.0
# 3                                               44.1
# 4                                               45.0
#
# [5 rows x 55 columns]

# %%
data_df.columns
# Out:
# Index(['Zip_Code', 'Households_Total', 'Households_Total_Less than $10,000',
#        'Households_Total_$10,000 to $14,999',
#        'Households_Total_$15,000 to $24,999',
#        'Households_Total_$25,000 to $34,999',
#        'Households_Total_$35,000 to $49,999',
#        'Households_Total_$50,000 to $74,999',
#        'Households_Total_$75,000 to $99,999',
#        'Households_Total_$100,000 to $149,999',
#        'Households_Total_$150,000 to $199,999',
#        'Households_Total_$200,000 or more',
#        'Households_Median income (dollars)',
#        'Households_Mean income (dollars)',
#        'Households_PERCENT ALLOCATED_Household income in the past 12 months',
#        'Families_Total', 'Families_Total_Less than $10,000',
#        'Families_Total_$10,000 to $14,999',
#        'Families_Total_$15,000 to $24,999',
#        'Families_Total_$25,000 to $34,999',
#        'Families_Total_$35,000 to $49,999',
#        'Families_Total_$50,000 to $74,999',
#        'Families_Total_$75,000 to $99,999',
#        'Families_Total_$100,000 to $149,999',
#        'Families_Total_$150,000 to $199,999',
#        'Families_Total_$200,000 or more', 'Families_Median income (dollars)',
#        'Families_Mean income (dollars)',
#        'Families_PERCENT ALLOCATED_Family income in the past 12 months',
#        'Married-couple families_Total',
#        'Married-couple families_Total_Less than $10,000',
#        'Married-couple families_Total_$10,000 to $14,999',
#        'Married-couple families_Total_$15,000 to $24,999',
#        'Married-couple families_Total_$25,000 to $34,999',
#        'Married-couple families_Total_$35,000 to $49,999',
#        'Married-couple families_Total_$50,000 to $74,999',
#        'Married-couple families_Total_$75,000 to $99,999',
#        'Married-couple families_Total_$100,000 to $149,999',
#        'Married-couple families_Total_$150,000 to $199,999',
#        'Married-couple families_Total_$200,000 or more',
#        'Married-couple families_Median income (dollars)',
#        'Nonfamily households_Total',
#        'Nonfamily households_Total_Less than $10,000',
#        'Nonfamily households_Total_$10,000 to $14,999',
#        'Nonfamily households_Total_$15,000 to $24,999',
#        'Nonfamily households_Total_$25,000 to $34,999',
#        'Nonfamily households_Total_$35,000 to $49,999',
#        'Nonfamily households_Total_$50,000 to $74,999',
#        'Nonfamily households_Total_$75,000 to $99,999',
#        'Nonfamily households_Total_$100,000 to $149,999',
#        'Nonfamily households_Total_$150,000 to $199,999',
#        'Nonfamily households_Total_$200,000 or more',
#        'Nonfamily households_Median income (dollars)',
#        'Nonfamily households_Mean income (dollars)',
#        'Nonfamily households_PERCENT ALLOCATED_Nonfamily income in the past 12 months'],
#       dtype='object')

# %%
household_df = data_df[['Zip_Code', 'Households_Total',
       'Households_Total_Less than $10,000',
       'Households_Total_$10,000 to $14,999',
       'Households_Total_$15,000 to $24,999',
       'Households_Total_$25,000 to $34,999',
       'Households_Total_$35,000 to $49,999',
       'Households_Total_$50,000 to $74,999',
       'Households_Total_$75,000 to $99,999',
       'Households_Total_$100,000 to $149,999',
       'Households_Total_$150,000 to $199,999',
       'Households_Total_$200,000 or more',
       'Households_Median income (dollars)',
       'Households_Mean income (dollars)',
       'Households_PERCENT ALLOCATED_Household income in the past 12 months']]

clean_household_df = data_df[['Zip_Code', 'Households_Total',
       'Households_Median income (dollars)',
       'Households_Mean income (dollars)',
       'Households_PERCENT ALLOCATED_Household income in the past 12 months']]


clean_household_df.head()
# Out:
#    Zip_Code  Households_Total  Households_Median income (dollars)  \
# 0     91901            6150.0                             93214.0
# 1     91902            6045.0                            106769.0
# 2     91906            1282.0                             48100.0
# 3     91910           24599.0                             70283.0
# 4     91911           25145.0                             65074.0
#
#    Households_Mean income (dollars)  \
# 0                          119653.0
# 1                          132519.0
# 2                           69435.0
# 3                           90646.0
# 4                           82231.0
#
#    Households_PERCENT ALLOCATED_Household income in the past 12 months
# 0                                               37.2
# 1                                               46.6
# 2                                               26.6
# 3                                               46.8
# 4                                               50.9

# %%
families_df = data_df[['Zip_Code', 'Families_Total', 
       'Families_Total_Less than $10,000',
       'Families_Total_$10,000 to $14,999',
       'Families_Total_$15,000 to $24,999',
       'Families_Total_$25,000 to $34,999',
       'Families_Total_$35,000 to $49,999',
       'Families_Total_$50,000 to $74,999',
       'Families_Total_$75,000 to $99,999',
       'Families_Total_$100,000 to $149,999',
       'Families_Total_$150,000 to $199,999',
       'Families_Total_$200,000 or more', 'Families_Median income (dollars)',
       'Families_Mean income (dollars)',
       'Families_PERCENT ALLOCATED_Family income in the past 12 months']]

clean_family_df = families_df[['Zip_Code', 'Families_Total', 
       'Families_Median income (dollars)',
       'Families_Mean income (dollars)',
       'Families_PERCENT ALLOCATED_Family income in the past 12 months']]

clean_family_df.head()
# Out:
#    Zip_Code  Families_Total  Families_Median income (dollars)  \
# 0     91901          4584.0                          106557.0
# 1     91902          4286.0                          123750.0
# 2     91906           911.0                           64073.0
# 3     91910         17756.0                           79589.0
# 4     91911         20275.0                           73924.0
#
#    Families_Mean income (dollars)  \
# 0                        134334.0
# 1                        138268.0
# 2                         80774.0
# 3                        100880.0
# 4                         88765.0
#
#    Families_PERCENT ALLOCATED_Family income in the past 12 months
# 0                                               41.7
# 1                                               43.1
# 2                                               22.0
# 3                                               46.8
# 4                                               51.5

# %%
nonfamily_df = data_df[['Zip_Code','Nonfamily households_Total',
       'Nonfamily households_Total_Less than $10,000',
       'Nonfamily households_Total_$10,000 to $14,999',
       'Nonfamily households_Total_$15,000 to $24,999',
       'Nonfamily households_Total_$25,000 to $34,999',
       'Nonfamily households_Total_$35,000 to $49,999',
       'Nonfamily households_Total_$50,000 to $74,999',
       'Nonfamily households_Total_$75,000 to $99,999',
       'Nonfamily households_Total_$100,000 to $149,999',
       'Nonfamily households_Total_$150,000 to $199,999',
       'Nonfamily households_Total_$200,000 or more',
       'Nonfamily households_Median income (dollars)',
       'Nonfamily households_Mean income (dollars)',
       'Nonfamily households_PERCENT ALLOCATED_Nonfamily income in the past 12 months']]

clean_nonfamily_df = nonfamily_df[['Zip_Code','Nonfamily households_Total',
       'Nonfamily households_Median income (dollars)',
       'Nonfamily households_Mean income (dollars)',
       'Nonfamily households_PERCENT ALLOCATED_Nonfamily income in the past 12 months']]

clean_nonfamily_df.head()
# Out:
#    Zip_Code  Nonfamily households_Total  \
# 0     91901                      1566.0
# 1     91902                      1759.0
# 2     91906                       371.0
# 3     91910                      6843.0
# 4     91911                      4870.0
#
#    Nonfamily households_Median income (dollars)  \
# 0                                       43523.0
# 1                                       70469.0
# 2                                       35991.0
# 3                                       40825.0
# 4                                       33231.0
#
#    Nonfamily households_Mean income (dollars)  \
# 0                                     62711.0
# 1                                    111325.0
# 2                                     37850.0
# 3                                     56747.0
# 4                                     45098.0
#
#    Nonfamily households_PERCENT ALLOCATED_Nonfamily income in the past 12 months
# 0                                               22.2
# 1                                               53.8
# 2                                               38.0
# 3                                               44.1
# 4                                               45.0

# %%
# Export dataframe as js file 
output_file = 'static/js/household_data.js'
clean_household_df.to_json(output_file, orient='records')

# %%
# Export dataframe as js file 
output_file = 'static/js/family_data.js'
clean_family_df.to_json(output_file, orient='records')

# %%
# Export dataframe as js file 
output_file = 'static/js/nonfamily_data.js'
clean_nonfamily_df.to_json(output_file, orient='records')

# %%
# Export dataframe as js file 
output_file = 'static/js/zip_codes.json'
data_df['Zip_Code'].astype(str).to_json(output_file, orient='split')

# %%
# Export dataframe as js file 
#output_file = 'static/js/data.json'
#data_df.to_json(output_file, orient='index')
