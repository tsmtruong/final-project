# %%
# import dependencies
import pandas as pd
from geopy.geocoders import Nominatim
import requests
import json
import gmaps
from pandas import json_normalize

# %%
# read in dataset

housing_data = pd.read_csv("Resources/Clean/Housing_Data - Horizontal_Data.csv")
housing_data.head()
# Out:
#    Unnamed: 0  Estimate_Households_Total  Households_Total_Less than $10,000  \
# 0       91901                       6150                                 148
# 1       91902                       6045                                 169
# 2       91906                       1282                                  59
# 3       91910                      24599                                1082
# 4       91911                      25145                                 805
#
#    Households_Total_$10,000 to $14,999  Households_Total_$15,000 to $24,999  \
# 0                                   62                                  326
# 1                                   36                                  187
# 2                                   35                                   95
# 3                                 1328                                 1648
# 4                                 1308                                 1936
#
#    Households_Total_$25,000 to $34,999  Households_Total_$35,000 to $49,999  \
# 0                                  646                                  492
# 1                                  308                                  459
# 2                                  162                                  347
# 3                                 2263                                 2558
# 4                                 2439                                 2791
#
#    Households_Total_$50,000 to $74,999  Affordable housing benfit zone   \
# 0                                  578                             1716
# 1                                  731                             1498
# 2                                  144                              653
# 3                                 4182                             9003
# 4                                 4702                             9932
#
#    Households_Total_$75,000 to $99,999  ...  \
# 0                                 1009  ...
# 1                                  864  ...
# 2                                   82  ...
# 3                                 3247  ...
# 4                                 3043  ...
#
#    Nonfamily households_Total_$25,000 to $34,999  \
# 0                                            366
# 1                                            237
# 2                                             33
# 3                                            766
# 4                                            818
#
#    Nonfamily households_Total_$35,000 to $49,999  \
# 0                                            232
# 1                                            336
# 2                                            152
# 3                                            814
# 4                                            687
#
#    Nonfamily households_Total_$50,000 to $74,999  \
# 0                                            218
# 1                                            172
# 2                                             26
# 3                                           1232
# 4                                            760
#
#    Nonfamily households_Total_$75,000 to $99,999  \
# 0                                            197
# 1                                            245
# 2                                              3
# 3                                            746
# 4                                            414
#
#    Nonfamily households_Total_$100,000 to $149,999  \
# 0                                              193
# 1                                              327
# 2                                                0
# 3                                              623
# 4                                              307
#
#    Nonfamily households_Total_$150,000 to $199,999  \
# 0                                               52
# 1                                              137
# 2                                               16
# 3                                              164
# 4                                               78
#
#    Nonfamily households_Total_$200,000 or more  \
# 0                                           31
# 1                                          130
# 2                                            0
# 3                                          198
# 4                                           34
#
#    Nonfamily households_Median income (dollars)  \
# 0                                       43523.0
# 1                                       70469.0
# 2                                       35991.0
# 3                                       40825.0
# 4                                       33231.0
#
#    Nonfamily households_Mean income (dollars)  \
# 0                                     62711.0
# 1                                    111325.0
# 2                                     37850.0
# 3                                     56747.0
# 4                                     45098.0
#
#    Nonfamily_Income_Allocated_for_Housing_Percent
# 0                                           0.222
# 1                                           0.538
# 2                                           0.380
# 3                                           0.441
# 4                                           0.450
#
# [5 rows x 56 columns]

# %%
# printing column names
for col in housing_data.columns:
    print(col)
# Out:
# Unnamed: 0
# Estimate_Households_Total
# Households_Total_Less than $10,000
# Households_Total_$10,000 to $14,999
# Households_Total_$15,000 to $24,999
# Households_Total_$25,000 to $34,999
# Households_Total_$35,000 to $49,999
# Households_Total_$50,000 to $74,999
# Affordable housing benfit zone
# Households_Total_$75,000 to $99,999
# Households_Total_$100,000 to $149,999
# Households_Total_$150,000 to $199,999
# Households_Total_$200,000+
# Median income (dollars)
# Mean income (dollars)
# Household_Income_Allocated_for_Housing_Percent
# Families_Total
# Families_Total_Less than $10,000
# Families_Total_$10,000 to $14,999
# Families_Total_$15,000 to $24,999
# Families_Total_$25,000 to $34,999
# Families_Total_$35,000 to $49,999
# Families_Total_$50,000 to $74,999
# Families_Total_$75,000 to $99,999
# Families_Total_$100,000 to $149,999
# Families_Total_$150,000 to $199,999
# Families_Total_$200,000 or more
# Families_Median income (dollars)
# Families_Mean income (dollars)
# Family_Income_Allocated_for_Housing_Percent
# Estimate_Married-couple families_Total
# Married-couple_Total_Less than $10,000
# Married-couple_Total_$10,000 to $14,999
# Married-couple_Total_$15,000 to $24,999
# Married-couple_Total_$25,000 to $34,999
# Married-couple_Total_$35,000 to $49,999
# Married-couple_Total_$50,000 to $74,999
# Married-couple_Total_$75,000 to $99,999
# Married-couple_Total_$100,000 to $149,999
# Married-couple_Total_$150,000 to $199,999
# Married-couple_Total_$200,000 or more
# Married-couple_Median income (dollars)
# Nonfamily households_Total
# Nonfamily households_Total_Less than $10,000
# Nonfamily households_Total_$10,000 to $14,999
# Nonfamily households_Total_$15,000 to $24,999
# Nonfamily households_Total_$25,000 to $34,999
# Nonfamily households_Total_$35,000 to $49,999
# Nonfamily households_Total_$50,000 to $74,999
# Nonfamily households_Total_$75,000 to $99,999
# Nonfamily households_Total_$100,000 to $149,999
# Nonfamily households_Total_$150,000 to $199,999
# Nonfamily households_Total_$200,000 or more
# Nonfamily households_Median income (dollars)
# Nonfamily households_Mean income (dollars)
# Nonfamily_Income_Allocated_for_Housing_Percent

# %%
# renaming columns
housing_data = housing_data.rename(columns={'Unnamed: 0':'zipcode'})
housing_data.head()
# Out:
#    zipcode  Estimate_Households_Total  Households_Total_Less than $10,000  \
# 0    91901                       6150                                 148
# 1    91902                       6045                                 169
# 2    91906                       1282                                  59
# 3    91910                      24599                                1082
# 4    91911                      25145                                 805
#
#    Households_Total_$10,000 to $14,999  Households_Total_$15,000 to $24,999  \
# 0                                   62                                  326
# 1                                   36                                  187
# 2                                   35                                   95
# 3                                 1328                                 1648
# 4                                 1308                                 1936
#
#    Households_Total_$25,000 to $34,999  Households_Total_$35,000 to $49,999  \
# 0                                  646                                  492
# 1                                  308                                  459
# 2                                  162                                  347
# 3                                 2263                                 2558
# 4                                 2439                                 2791
#
#    Households_Total_$50,000 to $74,999  Affordable housing benfit zone   \
# 0                                  578                             1716
# 1                                  731                             1498
# 2                                  144                              653
# 3                                 4182                             9003
# 4                                 4702                             9932
#
#    Households_Total_$75,000 to $99,999  ...  \
# 0                                 1009  ...
# 1                                  864  ...
# 2                                   82  ...
# 3                                 3247  ...
# 4                                 3043  ...
#
#    Nonfamily households_Total_$25,000 to $34,999  \
# 0                                            366
# 1                                            237
# 2                                             33
# 3                                            766
# 4                                            818
#
#    Nonfamily households_Total_$35,000 to $49,999  \
# 0                                            232
# 1                                            336
# 2                                            152
# 3                                            814
# 4                                            687
#
#    Nonfamily households_Total_$50,000 to $74,999  \
# 0                                            218
# 1                                            172
# 2                                             26
# 3                                           1232
# 4                                            760
#
#    Nonfamily households_Total_$75,000 to $99,999  \
# 0                                            197
# 1                                            245
# 2                                              3
# 3                                            746
# 4                                            414
#
#    Nonfamily households_Total_$100,000 to $149,999  \
# 0                                              193
# 1                                              327
# 2                                                0
# 3                                              623
# 4                                              307
#
#    Nonfamily households_Total_$150,000 to $199,999  \
# 0                                               52
# 1                                              137
# 2                                               16
# 3                                              164
# 4                                               78
#
#    Nonfamily households_Total_$200,000 or more  \
# 0                                           31
# 1                                          130
# 2                                            0
# 3                                          198
# 4                                           34
#
#    Nonfamily households_Median income (dollars)  \
# 0                                       43523.0
# 1                                       70469.0
# 2                                       35991.0
# 3                                       40825.0
# 4                                       33231.0
#
#    Nonfamily households_Mean income (dollars)  \
# 0                                     62711.0
# 1                                    111325.0
# 2                                     37850.0
# 3                                     56747.0
# 4                                     45098.0
#
#    Nonfamily_Income_Allocated_for_Housing_Percent
# 0                                           0.222
# 1                                           0.538
# 2                                           0.380
# 3                                           0.441
# 4                                           0.450
#
# [5 rows x 56 columns]

# %%
# making new dataframe
zipcode_df = housing_data[['zipcode']]
zipcode_df
# Out:
#     zipcode
# 0     91901
# 1     91902
# 2     91906
# 3     91910
# 4     91911
# ..      ...
# 82    92131
# 83    92139
# 84    92154
# 85    92173
# 86    92672
#
# [87 rows x 1 columns]

# %%
# reading in zipcode csv

us_zip = pd.read_csv("Resources/RAW/uszips.csv")
us_zip.head()
# Out:
#    zip       lat       lng       city state_id   state_name  zcta  \
# 0  601  18.18027 -66.75266   Adjuntas       PR  Puerto Rico  True
# 1  602  18.36075 -67.17541     Aguada       PR  Puerto Rico  True
# 2  603  18.45744 -67.12225  Aguadilla       PR  Puerto Rico  True
# 3  606  18.16585 -66.93716    Maricao       PR  Puerto Rico  True
# 4  610  18.29110 -67.12243     Anasco       PR  Puerto Rico  True
#
#    parent_zcta  population  density  county_fips county_name  \
# 0          NaN     16773.0    100.5        72001    Adjuntas
# 1          NaN     37083.0    472.1        72003      Aguada
# 2          NaN     45652.0    513.2        72005   Aguadilla
# 3          NaN      6231.0     54.3        72093     Maricao
# 4          NaN     26502.0    275.7        72011      Añasco
#
#                                       county_weights  \
# 0                    {"72001": 98.73, "72141": 1.27}
# 1                                     {"72003": 100}
# 2                    {"72005": 99.76, "72099": 0.24}
# 3    {"72093": 82.26, "72153": 11.68, "72121": 6.06}
# 4  {"72011": 96.71, "72099": 2.81, "72083": 0.37,...
#
#                 county_names_all          county_fips_all  imprecise  \
# 0                Adjuntas|Utuado              72001|72141      False
# 1                         Aguada                    72003      False
# 2                 Aguadilla|Moca              72005|72099      False
# 3    Maricao|Yauco|Sabana Grande        72093|72153|72121      False
# 4  Añasco|Moca|Las Marías|Aguada  72011|72099|72083|72003      False
#
#    military             timezone
# 0     False  America/Puerto_Rico
# 1     False  America/Puerto_Rico
# 2     False  America/Puerto_Rico
# 3     False  America/Puerto_Rico
# 4     False  America/Puerto_Rico

# %%
lat_lng = us_zip[['zip', 'lat', 'lng']]
lat_lng.head()
# Out:
#    zip       lat       lng
# 0  601  18.18027 -66.75266
# 1  602  18.36075 -67.17541
# 2  603  18.45744 -67.12225
# 3  606  18.16585 -66.93716
# 4  610  18.29110 -67.12243

# %%
lat_lng = lat_lng.rename(columns={'zip':'zipcode'})
lat_lng.head()
# Out:
#    zipcode       lat       lng
# 0      601  18.18027 -66.75266
# 1      602  18.36075 -67.17541
# 2      603  18.45744 -67.12225
# 3      606  18.16585 -66.93716
# 4      610  18.29110 -67.12243

# %%
zip_lat = zipcode_df.merge(lat_lng, on='zipcode')
zip_lat.head(20)
# Out:
#     zipcode       lat        lng
# 0     91901  32.81467 -116.71929
# 1     91902  32.67479 -117.00475
# 2     91906  32.66241 -116.47255
# 3     91910  32.63653 -117.06301
# 4     91911  32.60686 -117.04984
# 5     91913  32.62174 -116.98609
# 6     91914  32.66604 -116.95426
# 7     91915  32.62266 -116.95013
# 8     91932  32.56923 -117.11798
# 9     91935  32.70214 -116.78721
# 10    91941  32.75964 -116.99253
# 11    91942  32.77728 -117.02129
# 12    91945  32.73315 -117.03402
# 13    91950  32.66952 -117.09313
# 14    91977  32.72387 -116.99631
# 15    91978  32.71209 -116.94103
# 16    92003  33.28701 -117.19977
# 17    92004  33.18481 -116.15688
# 18    92007  33.02216 -117.27389
# 19    92008  33.14564 -117.31691

# %%
# combining columns
zip_lat['lat_lng'] = zip_lat[['lat', 'lng']].apply(tuple, axis=1)
zip_lat
# Out:
#     zipcode       lat        lng                 lat_lng
# 0     91901  32.81467 -116.71929  (32.81467, -116.71929)
# 1     91902  32.67479 -117.00475  (32.67479, -117.00475)
# 2     91906  32.66241 -116.47255  (32.66241, -116.47255)
# 3     91910  32.63653 -117.06301  (32.63653, -117.06301)
# 4     91911  32.60686 -117.04984  (32.60686, -117.04984)
# ..      ...       ...        ...                     ...
# 82    92131  32.89604 -117.05737  (32.89604, -117.05737)
# 83    92139  32.68006 -117.04889  (32.68006, -117.04889)
# 84    92154  32.57800 -116.96621    (32.578, -116.96621)
# 85    92173  32.55552 -117.05114  (32.55552, -117.05114)
# 86    92672  33.38250 -117.54030    (33.3825, -117.5403)
#
# [87 rows x 4 columns]

# %%
zip_lat.set_index(['zipcode'], inplace=True)

# %%
# API KEY 
API_KEY = "AIzaSyDit9o30tySl5bCODBNM5wI9fNFl0rHtLg" # API KEY HERE

# %%
# setting parameters
params = {
    "radius": 5000,
    "type": 'supermarket',
    "key": API_KEY
}

# %%
# Iterate the responses and filter out market names in a zipcode.
market_list = []

for index, row in zip_lat.iterrows():
    lat = zip_lat.loc[index, 'lat']
    lng = zip_lat.loc[index, 'lng']
    
    
    params["location"] = f"{lat},{lng}"
    
    base_url= "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    markets = requests.get(base_url,params=params).json()

    market_list.extend(markets.get('results'))

# %%
lat = zip_lat['lat']
lng = zip_lat['lng']

# %%
len(market_list)
# Out:
# 517

# %%
market_list[0]['geometry']['location']
# Out:
# {'lat': 32.6389997, 'lng': -117.050924}

# %%
df2 = pd.DataFrame([x['business_status'] for x in market_list])
df2
# Out:
#                       0
# 0           OPERATIONAL
# 1           OPERATIONAL
# 2           OPERATIONAL
# 3           OPERATIONAL
# 4           OPERATIONAL
# ..                  ...
# 512         OPERATIONAL
# 513         OPERATIONAL
# 514  CLOSED_TEMPORARILY
# 515         OPERATIONAL
# 516         OPERATIONAL
#
# [517 rows x 1 columns]

# %%
df2.set_axis(['business_status'], axis='columns', inplace=True)
df2
# Out:
#         business_status
# 0           OPERATIONAL
# 1           OPERATIONAL
# 2           OPERATIONAL
# 3           OPERATIONAL
# 4           OPERATIONAL
# ..                  ...
# 512         OPERATIONAL
# 513         OPERATIONAL
# 514  CLOSED_TEMPORARILY
# 515         OPERATIONAL
# 516         OPERATIONAL
#
# [517 rows x 1 columns]

# %%
df3 = pd.DataFrame([x['name'] for x in market_list])
df3.set_axis(['name'],axis='columns', inplace=True)
df3
# Out:
#                                                  name
# 0                                Smart & Final Extra!
# 1                              Sprouts Farmers Market
# 2                                Carnival Supermarket
# 3                                      Target Grocery
# 4                                     99 Ranch Market
# ..                                                ...
# 512                           Abarrotes La Tepexpense
# 513                                           Waldo's
# 514                                Farmamil chaparral
# 515                              Abarrotes La Placita
# 516  San Onofre Commissary- Defense Commissary agency
#
# [517 rows x 1 columns]

# %%
df4 = pd.DataFrame([x['geometry']['location'] for x in market_list])
df4
# Out:
#            lat         lng
# 0    32.639000 -117.050924
# 1    32.627807 -117.074994
# 2    32.621859 -117.072892
# 3    32.653616 -117.065593
# 4    32.629342 -117.040931
# ..         ...         ...
# 512  32.538416 -117.066559
# 513  32.534882 -117.040981
# 514  32.540419 -117.031336
# 515  32.535808 -117.037852
# 516  33.385571 -117.580131
#
# [517 rows x 2 columns]

# %%
final_market_df = pd.concat([df2, df3, df4], axis = 1)
final_market_df
# Out:
#         business_status                                              name  \
# 0           OPERATIONAL                              Smart & Final Extra!
# 1           OPERATIONAL                            Sprouts Farmers Market
# 2           OPERATIONAL                              Carnival Supermarket
# 3           OPERATIONAL                                    Target Grocery
# 4           OPERATIONAL                                   99 Ranch Market
# ..                  ...                                               ...
# 512         OPERATIONAL                           Abarrotes La Tepexpense
# 513         OPERATIONAL                                           Waldo's
# 514  CLOSED_TEMPORARILY                                Farmamil chaparral
# 515         OPERATIONAL                              Abarrotes La Placita
# 516         OPERATIONAL  San Onofre Commissary- Defense Commissary agency
#
#            lat         lng
# 0    32.639000 -117.050924
# 1    32.627807 -117.074994
# 2    32.621859 -117.072892
# 3    32.653616 -117.065593
# 4    32.629342 -117.040931
# ..         ...         ...
# 512  32.538416 -117.066559
# 513  32.534882 -117.040981
# 514  32.540419 -117.031336
# 515  32.535808 -117.037852
# 516  33.385571 -117.580131
#
# [517 rows x 4 columns]

# %%
# exporting file
from pathlib import Path

filepath = Path("Resources/Clean/markets.csv")
final_market_df.to_csv(filepath)
