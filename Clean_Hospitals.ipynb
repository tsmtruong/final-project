# %%
# import dependencies
import pandas as pd
import os
import glob
import requests

# %%
# setting path
files = os.path.join("Resources/RAW/hospitals/ushospitalfinder*")

#list of merged files returned
files = glob.glob(files)

# joining files
hospital_df = pd.concat(map(pd.read_csv, files), ignore_index=True)
hospital_df.head(10)
# Out:
#                    hospital_name  \
# 0      Sharp Chula Vista Med Ctr
# 1   Bayview Hosp & Mental System
# 2       Paradise Valley Hospital
# 3        Sharp Coronado Hospital
# 4  Rady Children Hosp & Hlth Ctr
# 5           Naval Medical Center
# 6  Promise Hospital of San Diego
# 7     Kindred Hospital-San Diego
# 8     Continental Rehab Hospital
# 9         Scripps Mercy Hospital
#
#                                              address  even  even 2
# 0  751 Medical Center Court  Chula Vista, CA 9191...   NaN     NaN
# 1        330 Moss Street  Chula Vista, CA 91911-2005   NaN     NaN
# 2  2400 East Fourth Street  National City, CA 919...   NaN     NaN
# 3        250 Prospect Place  Coronado, CA 92118-1943   NaN     NaN
# 4      3020 Children's Way  San Diego, CA 92123-4282   NaN     NaN
# 5   34800 Bob Wilson Drive  San Diego, CA 92134-5000   NaN     NaN
# 6   5550 University Avenue  San Diego, CA 92105-2307   NaN     NaN
# 7  1940 El Cajon Boulevard  San Diego, CA 92104-1096   NaN     NaN
# 8         555 Washington Street  San Diego, CA 92103   NaN     NaN
# 9        4077 Fifth Avenue  San Diego, CA 92103-2105   NaN     NaN

# %%
#print column names
print(hospital_df.keys())
# Out:
# Index(['hospital_name', 'address', 'even', 'even 2'], dtype='object')

# %%
#dropping columns
clean_df = hospital_df.drop(['even','even 2'], axis=1)

clean_df.head()
# Out:
#                    hospital_name  \
# 0      Sharp Chula Vista Med Ctr
# 1   Bayview Hosp & Mental System
# 2       Paradise Valley Hospital
# 3        Sharp Coronado Hospital
# 4  Rady Children Hosp & Hlth Ctr
#
#                                              address
# 0  751 Medical Center Court  Chula Vista, CA 9191...
# 1        330 Moss Street  Chula Vista, CA 91911-2005
# 2  2400 East Fourth Street  National City, CA 919...
# 3        250 Prospect Place  Coronado, CA 92118-1943
# 4      3020 Children's Way  San Diego, CA 92123-4282

# %%
# dropping duplicates
hosp_df = clean_df.drop_duplicates(subset=['hospital_name'])

hosp_df.head()
# Out:
#                    hospital_name  \
# 0      Sharp Chula Vista Med Ctr
# 1   Bayview Hosp & Mental System
# 2       Paradise Valley Hospital
# 3        Sharp Coronado Hospital
# 4  Rady Children Hosp & Hlth Ctr
#
#                                              address
# 0  751 Medical Center Court  Chula Vista, CA 9191...
# 1        330 Moss Street  Chula Vista, CA 91911-2005
# 2  2400 East Fourth Street  National City, CA 919...
# 3        250 Prospect Place  Coronado, CA 92118-1943
# 4      3020 Children's Way  San Diego, CA 92123-4282

# %%
hosp_df.value_counts().sum()
# Out:
# 35

# %%
# extracting zipcodes

hosp_df['zipcode'] = hosp_df['address'].str[-10:]

hosp_df
# Out:
# /var/folders/jg/35qqdf9j6v74xwfm65sq9zdh0000gn/T/ipykernel_18828/3724301106.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   
# 45  555 East Valley Parkway  Escondido, CA 92025-3084  92025-3084
# 46           4002 Vista Way  Oceanside, CA 92056-4506  92056-4506
# 48                NULL  Camp Pendleton, CA 92055-5191  92055-5191
# 50    624 East Elder Street  Fallbrook, CA 92028-3099  92028-3099
# 57  25500 Medical Center Drive  Murrieta, CA 92562...  92562-5965
# 58  654 Camino De Los Mares  San Clemente, CA 9267...  92673-2827
# 59  36485 Inland Valley Drive  Wildomar, CA 92595-...  92595-9700
# 64  27700 Medical Center Road  Mission Viejo, CA 9...  92691-6426
# 65  27700 Medical Center Road  Mission Viejo, CA 9...  92691-6426
# 66   31872 Coast Highway  Laguna Beach, CA 92651-6775  92651-6775
# 68  24451 Health Center Drive  Laguna Hills, CA 92...  92653-3689

# %%
# take the last block of strings by splitting on a space and taking the last part
hosp_df['zipcodes'] = [x.split(' ')[-1] for x in hosp_df['address']]
# Check if any of them contains a -
hosp_df.loc[hosp_df['zipcodes'].str.contains('-')]
# Out:
# /var/folders/jg/35qqdf9j6v74xwfm65sq9zdh0000gn/T/ipykernel_18828/1191758777.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hosp_df['zipcodes'] = [x.split(' ')[-1] for x in hosp_df['address']]
#                      hospital_name  \
# 0        Sharp Chula Vista Med Ctr
# 1     Bayview Hosp & Mental System
# 2         Paradise Valley Hospital
# 3          Sharp Coronado Hospital
# 4    Rady Children Hosp & Hlth Ctr
# 5             Naval Medical Center
# 6    Promise Hospital of San Diego
# 7       Kindred Hospital-San Diego
# 9           Scripps Mercy Hospital
# 10    Alvarado Hosp Medical Center
# 11    Univ of CA San Diego Med Ctr
# 12               San Diego Hospice
# 13        Sharp Grossmont Hospital
# 14   San Diego Cnty Psych Hospital
# 15      Kaiser Foundation Hospital
# 17         Sharp Memorial Hospital
# 18  VA San Diego Healthcare System
# 19       Scripps Mem Hosp-La Jolla
# 20          Scripps Green Hospital
# 40       Aurora San Diego Hospital
# 41               Pomerado Hospital
# 44  Scripps Mem Hospital-Encinitas
# 45          Palomar Medical Center
# 46         Tri-City Medical Center
# 48                  Naval Hospital
# 50              Fallbrook Hospital
# 57   Rancho Springs Medical Center
# 58   Saddleback Mem Medical Center
# 59    Inland Valley Medical Center
# 64  Children's Hospital at Mission
# 65                Mission Hospital
# 66      South Coast Medical Center
# 68  Saddleback Memorial Med Center
#
#                                               address     zipcode    zipcodes
# 0   751 Medical Center Court  Chula Vista, CA 9191...  91911-6617  91911-6617
# 1         330 Moss Street  Chula Vista, CA 91911-2005  91911-2005  91911-2005
# 2   2400 East Fourth Street  National City, CA 919...  91950-2099  91950-2099
# 3         250 Prospect Place  Coronado, CA 92118-1943  92118-1943  92118-1943
# 4       3020 Children's Way  San Diego, CA 92123-4282  92123-4282  92123-4282
# 5    34800 Bob Wilson Drive  San Diego, CA 92134-5000  92134-5000  92134-5000
# 6    5550 University Avenue  San Diego, CA 92105-2307  92105-2307  92105-2307
# 92161    3350 Lajolla Village Drive  San Diego, CA 9216...  92161-0002
# 92562    25500 Medical Center Drive  Murrieta, CA 92562...  92562-5965
# 92595    36485 Inland Valley Drive  Wildomar, CA 92595-...  92595-9700
# 92651     31872 Coast Highway  Laguna Beach, CA 92651-6775  92651-6775
# 92653    24451 Health Center Drive  Laguna Hills, CA 92...  92653-3689
# 92673    654 Camino De Los Mares  San Clemente, CA 9267...  92673-2827
# 92691    27700 Medical Center Road  Mission Viejo, CA 9...  92691-6426
# 92691    27700 Medical Center Road  Mission Viejo, CA 9...  92691-6426

# %%
hosp_df.drop(['zipcodes'], axis=1, inplace = True)
hosp_df
# Out:
# /var/folders/jg/35qqdf9j6v74xwfm65sq9zdh0000gn/T/ipykernel_18828/3323489377.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hosp_df.drop(['zipcodes'], axis=1, inplace = True)
#                           hospital_name  \
# zipcode
# 91911         Sharp Chula Vista Med Ctr
# 91911      Bayview Hosp & Mental System
# 91942          Sharp Grossmont Hospital
# 91950          Paradise Valley Hospital
# 92024    Scripps Mem Hospital-Encinitas
# 92025            Palomar Medical Center
# 92028                Fallbrook Hospital
# 92037         Scripps Mem Hosp-La Jolla
# 92037            Scripps Green Hospital
# 92055                    Naval Hospital
# 92056           Tri-City Medical Center
# 92064                 Pomerado Hospital
# 92103                 San Diego Hospice
# 92103            Scripps Mercy Hospital
# 92103        Continental Rehab Hospital
# 92103      Univ of CA San Diego Med Ctr
# 92104        Kindred Hospital-San Diego
# 92105     Promise Hospital of San Diego
# 92110     San Diego Cnty Psych Hospital
# 92118           Sharp Coronado Hospital
# 92120        Kaiser Foundation Hospital
# 92120      Alvarado Hosp Medical Center
# 92123           Sharp Memorial Hospital
# 92123         Sharp Mary Birch Hospital
# 92123     Rady Children Hosp & Hlth Ctr
# 92128         Aurora San Diego Hospital
# 92134              Naval Medical Center
# 92161    VA San Diego Healthcare System
# 92562     Rancho Springs Medical Center
# 92595      Inland Valley Medical Center
# 92651        South Coast Medical Center
# 92653    Saddleback Memorial Med Center
# 92673     Saddleback Mem Medical Center
# 92691    Children's Hospital at Mission
# 92691                  Mission Hospital
#
#                                                    address
# zipcode
# 91911    751 Medical Center Court  Chula Vista, CA 9191...
# 91911          330 Moss Street  Chula Vista, CA 91911-2005
# 91942    5555 Grossmont Center Drive  La Mesa, CA 91942...
# 91950    2400 East Fourth Street  National City, CA 919...
# 92024         354 Santa Fe Drive  Encinitas, CA 92024-5182
# 92025    555 East Valley Parkway  Escondido, CA 92025-3084
# 92028      624 East Elder Street  Fallbrook, CA 92028-3099
# 92037         9888 Genesee Avenue  La Jolla, CA 92037-1200
# 92037    10666 North Torrey Pines Road  La Jolla, CA 92...
# 92055                  NULL  Camp Pendleton, CA 92055-5191
# 92056             4002 Vista Way  Oceanside, CA 92056-4506
# 92064            15615 Pomerado Road  Poway, CA 92064-2460
# 92103          4311 Third Avenue  San Diego, CA 92103-7499
# 92103          4077 Fifth Avenue  San Diego, CA 92103-2105
# 92103           555 Washington Street  San Diego, CA 92103
# 92103       200 West Arbor Drive  San Diego, CA 92103-8970
# 92104    1940 El Cajon Boulevard  San Diego, CA 92104-1096
# 92105     5550 University Avenue  San Diego, CA 92105-2307
# 92110      3853 Rosecrans Street  San Diego, CA 92110-3115
# 92118          250 Prospect Place  Coronado, CA 92118-1943
# 92120           4647 Zion Avenue  San Diego, CA 92120-2507
# 92120         6655 Alvarado Road  San Diego, CA 92120-5208
# 92123          7901 Frost Street  San Diego, CA 92123-2701
# 92123        3003 Health Center Drive  San Diego, CA 92123
# 92123        3020 Children's Way  San Diego, CA 92123-4282
# 92128    11878 Avenue Of Industry  San Diego, CA 92128-...
# 92134     34800 Bob Wilson Drive  San Diego, CA 92134-5000
# 92161    3350 Lajolla Village Drive  San Diego, CA 9216...
# 92562    25500 Medical Center Drive  Murrieta, CA 92562...
# 92595    36485 Inland Valley Drive  Wildomar, CA 92595-...
# 92651     31872 Coast Highway  Laguna Beach, CA 92651-6775
# 92653    24451 Health Center Drive  Laguna Hills, CA 92...
# 92673    654 Camino De Los Mares  San Clemente, CA 9267...
# 92691    27700 Medical Center Road  Mission Viejo, CA 9...
# 92691    27700 Medical Center Road  Mission Viejo, CA 9...

# %%
hosp_df.value_counts().sum()
# Out:
# 35

# %%
# link example format
# https://maps.googleapis.com/maps/api/geocode/json?address=1600+Amphitheatre+Parkway,+Mountain+View,+CA&key=YOUR_API_KEY
hosp_coords = []
key = 'AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w'
addresses = hosp_df['address'].tolist()
for addy in addresses: 
    
    # cleaning addresses for URL
    new_addy = addy.replace(" ", "+")
    new_addy = new_addy.replace(",", "")
    
    # URL for google geocode API
    hosp_link = f"https://maps.googleapis.com/maps/api/geocode/json?address={new_addy}&key={key}"
    
    # Make a 'Get' request for the school location data.
    hosp_location = requests.get(hosp_link)
    
    # Get the JSON data.
    hosp_data = hosp_location.json()
    lat = hosp_data["results"][0]["geometry"]["location"]["lat"]
    lng = hosp_data["results"][0]["geometry"]["location"]["lng"]
    
    print(new_addy)
    print(hosp_link)
    print(hosp_location)
    print(lat)
    print(lng)
    print()
    
    hosp_coords.append({"lat": lat,
                         "lng": lng})
# Out:
# 751+Medical+Center+Court++Chula+Vista+CA+91911-6617
# https://maps.googleapis.com/maps/api/geocode/json?address=751+Medical+Center+Court++Chula+Vista+CA+91911-6617&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.6193909
# -117.0222837
#
# 330+Moss+Street++Chula+Vista+CA+91911-2005
# https://maps.googleapis.com/maps/api/geocode/json?address=330+Moss+Street++Chula+Vista+CA+91911-2005&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.6175204
# -117.0713635
#
# 5555+Grossmont+Center+Drive++La+Mesa+CA+91942-3019
# https://maps.googleapis.com/maps/api/geocode/json?address=5555+Grossmont+Center+Drive++La+Mesa+CA+91942-3019&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.7816526
# -117.0083968
#
# 2400+East+Fourth+Street++National+City+CA+91950-2099
# https://maps.googleapis.com/maps/api/geocode/json?address=2400+East+Fourth+Street++National+City+CA+91950-2099&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.6851132
# -117.0828852
#
# 354+Santa+Fe+Drive++Encinitas+CA+92024-5182
# https://maps.googleapis.com/maps/api/geocode/json?address=354+Santa+Fe+Drive++Encinitas+CA+92024-5182&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 33.0383421
# -117.2844532
#
# 555+East+Valley+Parkway++Escondido+CA+92025-3084
# https://maps.googleapis.com/maps/api/geocode/json?address=555+East+Valley+Parkway++Escondido+CA+92025-3084&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 33.1248595
# -117.0758226
#
# 624+East+Elder+Street++Fallbrook+CA+92028-3099
# https://maps.googleapis.com/maps/api/geocode/json?address=624+East+Elder+Street++Fallbrook+CA+92028-3099&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 33.3807362
# -117.2446469
#
# 9888+Genesee+Avenue++La+Jolla+CA+92037-1200
# https://maps.googleapis.com/maps/api/geocode/json?address=9888+Genesee+Avenue++La+Jolla+CA+92037-1200&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.8851544
# -117.2255383
#
# 10666+North+Torrey+Pines+Road++La+Jolla+CA+92037-1093
# https://maps.googleapis.com/maps/api/geocode/json?address=10666+North+Torrey+Pines+Road++La+Jolla+CA+92037-1093&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.8970357
# -117.2427735
#
# NULL++Camp+Pendleton+CA+92055-5191
# https://maps.googleapis.com/maps/api/geocode/json?address=NULL++Camp+Pendleton+CA+92055-5191&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 33.3178416
# -117.3205123
#
# 4002+Vista+Way++Oceanside+CA+92056-4506
# https://maps.googleapis.com/maps/api/geocode/json?address=4002+Vista+Way++Oceanside+CA+92056-4506&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 33.1856484
# -117.2904359
#
# 15615+Pomerado+Road++Poway+CA+92064-2460
# https://maps.googleapis.com/maps/api/geocode/json?address=15615+Pomerado+Road++Poway+CA+92064-2460&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.9976735
# -117.0554052
#
# 4311+Third+Avenue++San+Diego+CA+92103-7499
# https://maps.googleapis.com/maps/api/geocode/json?address=4311+Third+Avenue++San+Diego+CA+92103-7499&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.7584651
# -117.1636985
#
# 4077+Fifth+Avenue++San+Diego+CA+92103-2105
# https://maps.googleapis.com/maps/api/geocode/json?address=4077+Fifth+Avenue++San+Diego+CA+92103-2105&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.7510887
# -117.1605559
#
# 555+Washington+Street++San+Diego+CA+92103
# https://maps.googleapis.com/maps/api/geocode/json?address=555+Washington+Street++San+Diego+CA+92103&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.7497461
# -117.1597937
#
# 200+West+Arbor+Drive++San+Diego+CA+92103-8970
# https://maps.googleapis.com/maps/api/geocode/json?address=200+West+Arbor+Drive++San+Diego+CA+92103-8970&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.7542698
# -117.166135
#
# 1940+El+Cajon+Boulevard++San+Diego+CA+92104-1096
# https://maps.googleapis.com/maps/api/geocode/json?address=1940+El+Cajon+Boulevard++San+Diego+CA+92104-1096&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.7563499
# -117.1442605
#
# 5550+University+Avenue++San+Diego+CA+92105-2307
# https://maps.googleapis.com/maps/api/geocode/json?address=5550+University+Avenue++San+Diego+CA+92105-2307&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.7495036
# -117.076742
#
# 3853+Rosecrans+Street++San+Diego+CA+92110-3115
# https://maps.googleapis.com/maps/api/geocode/json?address=3853+Rosecrans+Street++San+Diego+CA+92110-3115&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.7537242
# -117.2019715
#
# 250+Prospect+Place++Coronado+CA+92118-1943
# https://maps.googleapis.com/maps/api/geocode/json?address=250+Prospect+Place++Coronado+CA+92118-1943&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.6944471
# -117.168661
#
# 4647+Zion+Avenue++San+Diego+CA+92120-2507
# https://maps.googleapis.com/maps/api/geocode/json?address=4647+Zion+Avenue++San+Diego+CA+92120-2507&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.7916133
# -117.0954049
#
# 6655+Alvarado+Road++San+Diego+CA+92120-5208
# https://maps.googleapis.com/maps/api/geocode/json?address=6655+Alvarado+Road++San+Diego+CA+92120-5208&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.7766415
# -117.0573188
#
# 7901+Frost+Street++San+Diego+CA+92123-2701
# https://maps.googleapis.com/maps/api/geocode/json?address=7901+Frost+Street++San+Diego+CA+92123-2701&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.7995207
# -117.1546027
#
# 3003+Health+Center+Drive++San+Diego+CA+92123
# https://maps.googleapis.com/maps/api/geocode/json?address=3003+Health+Center+Drive++San+Diego+CA+92123&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.7983729
# -117.1550596
#
# 3020+Children's+Way++San+Diego+CA+92123-4282
# https://maps.googleapis.com/maps/api/geocode/json?address=3020+Children's+Way++San+Diego+CA+92123-4282&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.7977575
# -117.151407
#
# 11878+Avenue+Of+Industry++San+Diego+CA+92128-3423
# https://maps.googleapis.com/maps/api/geocode/json?address=11878+Avenue+Of+Industry++San+Diego+CA+92128-3423&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.9913251
# -117.0749492
#
# 34800+Bob+Wilson+Drive++San+Diego+CA+92134-5000
# https://maps.googleapis.com/maps/api/geocode/json?address=34800+Bob+Wilson+Drive++San+Diego+CA+92134-5000&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.7274239
# -117.1453405
#
# 3350+Lajolla+Village+Drive++San+Diego+CA+92161-0002
# https://maps.googleapis.com/maps/api/geocode/json?address=3350+Lajolla+Village+Drive++San+Diego+CA+92161-0002&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 32.8751298
# -117.2323881
#
# 25500+Medical+Center+Drive++Murrieta+CA+92562-5965
# https://maps.googleapis.com/maps/api/geocode/json?address=25500+Medical+Center+Drive++Murrieta+CA+92562-5965&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 33.5590999
# -117.1839646
#
# 36485+Inland+Valley+Drive++Wildomar+CA+92595-9700
# https://maps.googleapis.com/maps/api/geocode/json?address=36485+Inland+Valley+Drive++Wildomar+CA+92595-9700&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 33.5917132
# -117.2376587
#
# 31872+Coast+Highway++Laguna+Beach+CA+92651-6775
# https://maps.googleapis.com/maps/api/geocode/json?address=31872+Coast+Highway++Laguna+Beach+CA+92651-6775&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 33.5002569
# -117.7419417
#
# 24451+Health+Center+Drive++Laguna+Hills+CA+92653-3689
# https://maps.googleapis.com/maps/api/geocode/json?address=24451+Health+Center+Drive++Laguna+Hills+CA+92653-3689&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 33.6093252
# -117.7089298
#
# 654+Camino+De+Los+Mares++San+Clemente+CA+92673-2827
# https://maps.googleapis.com/maps/api/geocode/json?address=654+Camino+De+Los+Mares++San+Clemente+CA+92673-2827&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 33.4574842
# -117.6499245
#
# 27700+Medical+Center+Road++Mission+Viejo+CA+92691-6426
# https://maps.googleapis.com/maps/api/geocode/json?address=27700+Medical+Center+Road++Mission+Viejo+CA+92691-6426&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 33.56101530000001
# -117.6653937
#
# 27700+Medical+Center+Road++Mission+Viejo+CA+92691-6426
# https://maps.googleapis.com/maps/api/geocode/json?address=27700+Medical+Center+Road++Mission+Viejo+CA+92691-6426&key=AIzaSyA8r48O8blIHmLRGnsGi7zPLQJGn-Wbi1w
# <Response [200]>
# 33.56101530000001
# -117.6653937

# %%
hosp_geos_df = pd.DataFrame(hosp_coords, index=None, columns = ["lat", "lng"])
hosp_geos_df['zipcode'] = hosp_df.index
hosp_geos_df.set_index(['zipcode'],inplace=True)
hosp_geos_df.value_counts().sum()
# Out:
# 35

# %%
full_hosp_df = pd.merge(hosp_df, hosp_geos_df, left_index=True, right_index=True)
full_hosp_df
# Out:
#                           hospital_name  \
# zipcode
# 91911         Sharp Chula Vista Med Ctr
# 91911         Sharp Chula Vista Med Ctr
# 91911      Bayview Hosp & Mental System
# 91911      Bayview Hosp & Mental System
# 91942          Sharp Grossmont Hospital
# ...                                 ...
# 92673     Saddleback Mem Medical Center
# 92691    Children's Hospital at Mission
# 92691    Children's Hospital at Mission
# 92691                  Mission Hospital
# 92691                  Mission Hospital
#
#                                                    address        lat  \
# zipcode
# 91911    751 Medical Center Court  Chula Vista, CA 9191...  32.619391
# 91911    751 Medical Center Court  Chula Vista, CA 9191...  32.617520
# 91911          330 Moss Street  Chula Vista, CA 91911-2005  32.619391
# 91911          330 Moss Street  Chula Vista, CA 91911-2005  32.617520
# 91942    5555 Grossmont Center Drive  La Mesa, CA 91942...  32.781653
# ...                                                    ...        ...
# 92673    654 Camino De Los Mares  San Clemente, CA 9267...  33.457484
# 92691    27700 Medical Center Road  Mission Viejo, CA 9...  33.561015
# 92691    27700 Medical Center Road  Mission Viejo, CA 9...  33.561015
# 92691    27700 Medical Center Road  Mission Viejo, CA 9...  33.561015
# 92691    27700 Medical Center Road  Mission Viejo, CA 9...  33.561015
#
#                 lng
# zipcode
# 91911   -117.022284
# 91911   -117.071364
# 91911   -117.022284
# 91911   -117.071364
# 91942   -117.008397
# ...             ...
# 92673   -117.649924
# 92691   -117.665394
# 92691   -117.665394
# 92691   -117.665394
# 92691   -117.665394
#
# [61 rows x 4 columns]

# %%
# exporting file
from pathlib import Path

filepath = Path("Resources/Clean/San_Diego_Hospital_Data.csv")
hosp_df.to_csv(filepath)
